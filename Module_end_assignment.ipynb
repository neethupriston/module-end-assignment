# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv("C:/Users/neeth/Downloads/ABC Company.xlsx - Sheet1.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df['Height'] = np.random.randint(150, 180, size=len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     157     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     179     235
# 2     John Holland  Boston Celtics      30       SG   27     160     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     171     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     161     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     177     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     167     256
# 456    Jeff Withey       Utah Jazz      24        C   26     165     231
# 457       Priyanka       Utah Jazz      34        C   25     160     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.describe()
# Out:
#            Number         Age      Height      Weight        Salary
# count  458.000000  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  163.842795  221.543668  4.833970e+06
# std     15.966837    4.400128    8.646559   26.343200  5.226620e+06
# min      0.000000   19.000000  150.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  156.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  163.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  171.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  179.000000  307.000000  2.500000e+07

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
round((df.isnull().sum()/df.shape[0])*100,2)
# Out:
# Name         0.00
# Team         0.00
# Number       0.00
# Position     0.00
# Age          0.00
# Height       0.00
# Weight       0.00
# College     18.34
# Salary       2.40
# dtype: float64

# %%
df.dropna(subset=['Salary'],axis=0,inplace=True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     157     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     179     235
# 3      R.J. Hunter  Boston Celtics      28       SG   22     171     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     161     231
# 5     Amir Johnson  Boston Celtics      90       PF   29     176     240
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     177     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     167     256
# 456    Jeff Withey       Utah Jazz      24        C   26     165     231
# 457       Priyanka       Utah Jazz      34        C   25     160     231
#
#            College      Salary
# 0            Texas   7730337.0
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     82
# Salary       0
# dtype: int64

# %%
df.shape
# Out:
# (447, 9)

# %%
round((df.isnull().sum()/df.shape[0])*100,2)
# Out:
# Name         0.00
# Team         0.00
# Number       0.00
# Position     0.00
# Age          0.00
# Height       0.00
# Weight       0.00
# College     18.34
# Salary       0.00
# dtype: float64

# %%
df['College'] = df['College'].fillna('')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     157     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     179     235
# 3      R.J. Hunter  Boston Celtics      28       SG   22     171     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     161     231
# 5     Amir Johnson  Boston Celtics      90       PF   29     176     240
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     177     203
# 454      Raul Neto       Utah Jazz      25       PG   24     157     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     167     256
# 456    Jeff Withey       Utah Jazz      24        C   26     165     231
# 457       Priyanka       Utah Jazz      34        C   25     160     231
#
#            College      Salary
# 0            Texas   7730337.0
# ...

# %%
round((df.isnull().sum()/df.shape[0])*100,2)
# Out:
# Name        0.0
# Team        0.0
# Number      0.0
# Position    0.0
# Age         0.0
# Height      0.0
# Weight      0.0
# College     0.0
# Salary      0.0
# dtype: float64

# %%
Determine the distribution of employees across each team and calculate 
the percentage split relative to the total number of employees.

# %%
team_counts = df['Team'].value_counts()
team_counts
# Out:
# Team
# New Orleans Pelicans      19
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Indiana Pacers            15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Washington Wizards        15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Brooklyn Nets             15
# Dallas Mavericks          15
# Detroit Pistons           15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Cleveland Cavaliers       14
# Memphis Grizzlies         14
# Orlando Magic             14
# Denver Nuggets            14
# Philadelphia 76ers        14
# Boston Celtics            14
# Miami Heat                13
# Minnesota Timberwolves    13
# Name: count, dtype: int64

# %%
team_percentages = round((team_counts / df.shape[0]) * 100, 2)
team_percentages
# Out:
# Team
# New Orleans Pelicans      4.25
# Utah Jazz                 3.58
# New York Knicks           3.58
# Milwaukee Bucks           3.58
# Indiana Pacers            3.36
# Portland Trail Blazers    3.36
# Oklahoma City Thunder     3.36
# Washington Wizards        3.36
# Charlotte Hornets         3.36
# Atlanta Hawks             3.36
# San Antonio Spurs         3.36
# Houston Rockets           3.36
# Brooklyn Nets             3.36
# Dallas Mavericks          3.36
# Detroit Pistons           3.36
# Chicago Bulls             3.36
# Sacramento Kings          3.36
# Phoenix Suns              3.36
# Los Angeles Lakers        3.36
# Los Angeles Clippers      3.36
# Golden State Warriors     3.36
# Toronto Raptors           3.36
# Cleveland Cavaliers       3.13
# Memphis Grizzlies         3.13
# Orlando Magic             3.13
# Denver Nuggets            3.13
# Philadelphia 76ers        3.13
# Boston Celtics            3.13
# Miami Heat                2.91
# Minnesota Timberwolves    2.91
# ...

# %%
team_distribution = pd.DataFrame({
    'Employee Count': team_counts,
    'Percentage (%)': team_percentages})
team_distribution
# Out:
#                         Employee Count  Percentage (%)
# Team
# New Orleans Pelicans                19            4.25
# Utah Jazz                           16            3.58
# New York Knicks                     16            3.58
# Milwaukee Bucks                     16            3.58
# Indiana Pacers                      15            3.36
# Portland Trail Blazers              15            3.36
# Oklahoma City Thunder               15            3.36
# Washington Wizards                  15            3.36
# Charlotte Hornets                   15            3.36
# Atlanta Hawks                       15            3.36
# San Antonio Spurs                   15            3.36
# Houston Rockets                     15            3.36
# Brooklyn Nets                       15            3.36
# Dallas Mavericks                    15            3.36
# Detroit Pistons                     15            3.36
# Chicago Bulls                       15            3.36
# ...

# %%
plt.figure(figsize=(10, 6))
plt.bar(team_counts.index, team_percentages )
plt.xlabel("Team")
plt.ylabel("Percentage of Employees")
plt.title("Distribution of Employees Across Teams")
plt.xticks(rotation=45, ha="right")  
plt.tight_layout() 
plt.show()

# %% [markdown]
# New Orleans Pelicans is the Team with highest number of employees and Minnesota Timberwolves is the Team with lowest number of employees

# %% [markdown]
# Segregate employees based on their positions within the company.

# %%
position = df['Position'].value_counts()
position
# Out:
# Position
# SG    99
# PF    97
# PG    88
# SF    84
# C     79
# Name: count, dtype: int64

# %%
grouped_by_position = df.groupby(['Position'])
for position, group in grouped_by_position:
    print(f"\n--- {position} ---")
    print(group['Name'])
# Out:
# --- ('C',) ---
# 7         Kelly Olynyk
# 10     Jared Sullinger
# 14        Tyler Zeller
# 23         Brook Lopez
# 27          Henry Sims
#             ...
# 439      Mason Plumlee
# 447        Rudy Gobert
# 455       Tibor Pleiss
# 456        Jeff Withey
# 457           Priyanka
# Name: Name, Length: 79, dtype: object
#
# --- ('PF',) ---
# 4         Jonas Jerebko
# 5          Amir Johnson
# 6         Jordan Mickey
# 24     Chris McCullough
# 25          Willie Reed
#              ...
# 435      Meyers Leonard
# 441         Noah Vonleh
# 442       Trevor Booker
# 446      Derrick Favors
# 452          Trey Lyles
# Name: Name, Length: 97, dtype: object
#
# --- ('PG',) ---
# 0      Avery Bradley
# 8       Terry Rozier
# 9       Marcus Smart
# 11     Isaiah Thomas
# 19      Jarrett Jack
#            ...
# 440    Brian Roberts
# 443       Trey Burke
# 445       Dante Exum
# 453     Shelvin Mack
# 454        Raul Neto
# Name: Name, Length: 88, dtype: object
#
# --- ('SF',) ---
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Position'])  
plt.xlabel("Position")
plt.ylabel("Count")
plt.title("Position of employees")
plt.show()

# %% [markdown]
# SG is the position with highest number of employees

# %% [markdown]
# Identify the predominant age group among employees.

# %%
Age = df['Age'].value_counts()
Age
# Out:
# Age
# 25    45
# 24    45
# 27    40
# 23    39
# 26    36
# 28    30
# 30    30
# 29    27
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     8
# 38     4
# 37     3
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
sns.histplot(x='Age',kde=True,data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
25 is the predominent age group within the company

# %% [markdown]
# Discover which team and position have the highest salary expenditure.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Team', y='Salary', hue='Position', size='Salary', data=df)
plt.xticks(rotation=60, ha="right")
plt.xlabel('Team')
plt.ylabel('Total Salary Expenditure')
plt.title('Salary Expenditure by Team and Position')
plt.tight_layout()
plt.show()

# %% [markdown]
# SF is the position and Los Angeles Lakers is the team with highest salary expenditure

# %% [markdown]
# Investigate if there's any correlation between age and salary, and
# represent it visually.

# %%
sns.stripplot(x='Age',y='Salary',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %% [markdown]
# salary is incerasing with the Age but after 34 salary decreases as the age increases
